# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.0/874.0 kB 23.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO as yo
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = yo("yolov8n.pt") # Load the pre-trained YOLOv8n model
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 117MB/s]

# %%
urk_data = "/content/drive/MyDrive/Colab Notebooks/data_label/data.yaml"
 # Path to the YAML configuration file containing information about the dataset, such as image paths, labels, and data splits.

# %%
res = model.train(data = urk_data,epochs = 50, batch = 20)
# Train the model on the dataset specified in 'urk_data' for 50 epochs, using a batch size of 20. The training results are stored in the 'res' variable.
# Out:
# Ultralytics YOLOv8.2.99 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
